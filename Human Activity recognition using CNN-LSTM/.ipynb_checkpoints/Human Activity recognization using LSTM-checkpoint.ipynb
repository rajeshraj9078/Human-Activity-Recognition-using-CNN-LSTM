# %% [markdown]
# # Human Activity recogniztion using LSTM

# %% [markdown]
# # 1.Import libraris

# %%
# !pip install opencv-python mediapipe msvc-runtime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (4.8.0.76)
# Requirement already satisfied: mediapipe in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (0.10.3)
# Requirement already satisfied: msvc-runtime in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (14.34.31931)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: absl-py in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\rajesh raj\appdata\roaming\python\python311\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2.MP Holistic

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return image,results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face landmarks
    if results.face_landmarks is not None:
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                   mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                   mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

    # Draw pose landmarks
    if results.pose_landmarks is not None:
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                   mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2))

    # Draw left hand landmarks
    if results.left_hand_landmarks is not None:
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                   mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=1, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=1, circle_radius=2))
        
     # Draw right hand landmarks
    if results.right_hand_landmarks is not None:
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                   mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=1, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=1, circle_radius=2))

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      11 print(results)
#      13 # Draw landmarks
# ---> 14 draw_styled_landmarks(image, results)
#      16 # Show to screen
#      17 cv2.imshow('OpenCV Feed', image)
#
# Cell In[7], line 4, in draw_styled_landmarks(image, results)
#       1 def draw_styled_landmarks(image, results):
#       2     # Draw face landmarks
#       3     if results.face_landmarks is not None:
# ----> 4         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
#       5                                    mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
#       6                                    mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))
#       8     # Draw pose landmarks
#       9     if results.pose_landmarks is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mediapipe\python\solutions\drawing_utils.py:179, in draw_landmarks(image, landmark_list, connections, landmark_drawing_spec, connection_drawing_spec)
#     176     if start_idx in idx_to_coordinates and end_idx in idx_to_coordinates:
#     177       drawing_spec = connection_drawing_spec[connection] if isinstance(
#     178           connection_drawing_spec, Mapping) else connection_drawing_spec
# --> 179       cv2.line(image, idx_to_coordinates[start_idx],
#     180                idx_to_coordinates[end_idx], drawing_spec.color,
#     181                drawing_spec.thickness)
#     182 # Draws landmark points after finishing the connection lines, which is
#     183 # aesthetically better.
#     184 if landmark_drawing_spec:
#
# KeyboardInterrupt:

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3.Keypointy point value Extract

# %%
visibility_value = results.pose_landmarks.landmark[0].visibility

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    return np.concatenate([pose,face,lh,rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.63815469,  0.38593981, -0.96208322, ...,  0.        ,
#         0.        ,  0.        ])

# %%
468*3+33*4+21*3+21*3
# Out:
# 1662

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.63815469,  0.38593981, -0.96208322, ...,  0.        ,
#         0.        ,  0.        ])

# %%
DATA_PATH = os.path.join('MP_Data')
#Actions
actions = np.array(['hello','thanks','iloveyou'])
#30 videos worth of data
no_sequences = 30
#30 frames
sequence_length = 30
# Folder start
start_folder = 30

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)

#Mediapipe Model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    #Loop through Actions
    for action in actions:
        #Loop through Videos
        for sequence in range(no_sequences):
            #Loop through video length aka sequence length
            for frame_num in range(sequence_length):
                
        
                #Read Feed
                ret, frame = cap.read()

                #Make detections
                image,results = mediapipe_detection(frame,holistic)

                #Draw Styled Landmarks
                draw_styled_landmarks(image,results)
                
                #Wait Logic
                if frame_num==0:
                    cv2.putText(image,'Starting Collection',(120,200),
                                cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),4,cv2.LINE_AA)
                    cv2.putText(image,'Collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
                                cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),4,cv2.LINE_AA)
                    cv2.waitKey(2000)
                
                else:
                    cv2.putText(image,'Collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
                                cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),4,cv2.LINE_AA)

                #NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH,action,str(sequence), str(frame_num))
                np.save(npy_path,keypoints)
                
#                 # NEW Export keypoints
#                 keypoints = extract_keypoints(results)
#                 npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))

                # Create the directory if it doesn't exist
                os.makedirs(os.path.dirname(npy_path), exist_ok=True)

                np.save(npy_path, keypoints)
                
                #Show to Screen
                cv2.imshow('OpenCV feed', image)

                #Breaking the Feed
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 29
#      25     cv2.putText(image,'Starting Collection',(120,200),
#      26                 cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),4,cv2.LINE_AA)
#      27     cv2.putText(image,'Collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
#      28                 cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),4,cv2.LINE_AA)
# ---> 29     cv2.waitKey(2000)
#      31 else:
#      32     cv2.putText(image,'Collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
#      33                 cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),4,cv2.LINE_AA)
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Dense

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 21s 216ms/step - loss: 1.5425 - categorical_accuracy: 0.2941
# Epoch 2/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 4.0496 - categorical_accuracy: 0.3765
# Epoch 3/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 14.4334 - categorical_accuracy: 0.3882
# Epoch 4/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 8.8945 - categorical_accuracy: 0.4706
# Epoch 5/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 6.7635 - categorical_accuracy: 0.5059
# Epoch 6/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 15.8924 - categorical_accuracy: 0.3765
# Epoch 7/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 32.2107 - categorical_accuracy: 0.4000
# Epoch 8/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 33.4145 - categorical_accuracy: 0.2588
# Epoch 9/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 19.3931 - categorical_accuracy: 0.3765
# Epoch 10/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 9.1896 - categorical_accuracy: 0.4118
# Epoch 11/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 11.2254 - categorical_accuracy: 0.4706
# Epoch 12/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 14.4421 - categorical_accuracy: 0.4000
# Epoch 13/2000
# 3/3 [==============================] - 1s 171ms/step - loss: 17.9912 - categorical_accuracy: 0.4235
# Epoch 14/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 46.2751 - categorical_accuracy: 0.5294
# Epoch 15/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 65.7433 - categorical_accuracy: 0.4588
# Epoch 16/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 47.0570 - categorical_accuracy: 0.3059
# Epoch 17/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 28.3254 - categorical_accuracy: 0.3176
# Epoch 18/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 16.0468 - categorical_accuracy: 0.4353
# Epoch 19/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 8.3301 - categorical_accuracy: 0.3882
# Epoch 20/2000
# 3/3 [==============================] - 1s 215ms/step - loss: 6.0046 - categorical_accuracy: 0.5059
# Epoch 21/2000
# 3/3 [==============================] - 1s 174ms/step - loss: 8.1746 - categorical_accuracy: 0.3882
# Epoch 22/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 4.0912 - categorical_accuracy: 0.5412
# Epoch 23/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 4.8106 - categorical_accuracy: 0.4824
# Epoch 24/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 7.0645 - categorical_accuracy: 0.5647
# Epoch 25/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 5.2550 - categorical_accuracy: 0.5882
# Epoch 26/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 4.6678 - categorical_accuracy: 0.3412
# Epoch 27/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 2.9201 - categorical_accuracy: 0.4588
# Epoch 28/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 3.9388 - categorical_accuracy: 0.4235
# Epoch 29/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 1.7399 - categorical_accuracy: 0.4824
# Epoch 30/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 2.1931 - categorical_accuracy: 0.5294
# Epoch 31/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 2.6277 - categorical_accuracy: 0.4118
# Epoch 32/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 4.4286 - categorical_accuracy: 0.3176
# Epoch 33/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 2.6027 - categorical_accuracy: 0.5412
# Epoch 34/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 6.3658 - categorical_accuracy: 0.4588
# Epoch 35/2000
# 3/3 [==============================] - 0s 153ms/step - loss: 2.4051 - categorical_accuracy: 0.4235
# Epoch 36/2000
# 3/3 [==============================] - 0s 154ms/step - loss: 5.3028 - categorical_accuracy: 0.5647
# Epoch 37/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 5.1415 - categorical_accuracy: 0.4824
# Epoch 38/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 5.6839 - categorical_accuracy: 0.4706
# Epoch 39/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 1.6260 - categorical_accuracy: 0.4941
# Epoch 40/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 9.1241 - categorical_accuracy: 0.5529
# Epoch 41/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 9.6954 - categorical_accuracy: 0.3529
# Epoch 42/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 188.1060 - categorical_accuracy: 0.3294
# Epoch 43/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 549.2845 - categorical_accuracy: 0.4000
# Epoch 44/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 290.7704 - categorical_accuracy: 0.3882
# Epoch 45/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 636.3069 - categorical_accuracy: 0.2000
# Epoch 46/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 152.0419 - categorical_accuracy: 0.4000
# Epoch 47/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 111.0125 - categorical_accuracy: 0.3882
# Epoch 48/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 85.9329 - categorical_accuracy: 0.4118
# Epoch 49/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 179.4718 - categorical_accuracy: 0.3176
# Epoch 50/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 784.3038 - categorical_accuracy: 0.3412
# Epoch 51/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 442.5058 - categorical_accuracy: 0.3529
# Epoch 52/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 778.9158 - categorical_accuracy: 0.2706
# Epoch 53/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 970.0286 - categorical_accuracy: 0.4000
# Epoch 54/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 973.1056 - categorical_accuracy: 0.3294
# Epoch 55/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 1400.5106 - categorical_accuracy: 0.3412
# Epoch 56/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 2034.7823 - categorical_accuracy: 0.3529
# Epoch 57/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 3176.6045 - categorical_accuracy: 0.2471
# Epoch 58/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 2512.4158 - categorical_accuracy: 0.3529
# Epoch 59/2000
# 3/3 [==============================] - 1s 221ms/step - loss: 5545.9561 - categorical_accuracy: 0.3294
# Epoch 60/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 3692.8589 - categorical_accuracy: 0.3765
# Epoch 61/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 4022.3162 - categorical_accuracy: 0.1765
# Epoch 62/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 2044.3655 - categorical_accuracy: 0.3176
# Epoch 63/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 3746.9097 - categorical_accuracy: 0.3647
# Epoch 64/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 2149.2502 - categorical_accuracy: 0.4118
# Epoch 65/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 2541.5527 - categorical_accuracy: 0.2706
# Epoch 66/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 2679.5374 - categorical_accuracy: 0.3176
# Epoch 67/2000
# 3/3 [==============================] - 1s 225ms/step - loss: 1605.2167 - categorical_accuracy: 0.3882
# Epoch 68/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 1953.9879 - categorical_accuracy: 0.3882
# Epoch 69/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 5937.8193 - categorical_accuracy: 0.4353
# Epoch 70/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 5458.1392 - categorical_accuracy: 0.3294
# Epoch 71/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 4768.1333 - categorical_accuracy: 0.4588
# Epoch 72/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 3868.0107 - categorical_accuracy: 0.3412
# Epoch 73/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 6865.7075 - categorical_accuracy: 0.2706
# Epoch 74/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 4947.4658 - categorical_accuracy: 0.4235
# Epoch 75/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 10846.2207 - categorical_accuracy: 0.2471
# Epoch 76/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 11374.4531 - categorical_accuracy: 0.3059
# Epoch 77/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 7402.0903 - categorical_accuracy: 0.3294
# Epoch 78/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 10111.0029 - categorical_accuracy: 0.3412
# Epoch 79/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 7105.6235 - categorical_accuracy: 0.3647
# Epoch 80/2000
# 3/3 [==============================] - 1s 173ms/step - loss: 3470.9082 - categorical_accuracy: 0.2235
# Epoch 81/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 3953.6165 - categorical_accuracy: 0.3294
# Epoch 82/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 5112.2817 - categorical_accuracy: 0.3412
# Epoch 83/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 3276.0007 - categorical_accuracy: 0.2941
# Epoch 84/2000
# 3/3 [==============================] - 1s 224ms/step - loss: 2277.1924 - categorical_accuracy: 0.3294
# Epoch 85/2000
# 3/3 [==============================] - 1s 235ms/step - loss: 1644.7034 - categorical_accuracy: 0.3294
# Epoch 86/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 858.9105 - categorical_accuracy: 0.3529
# Epoch 87/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 1557.2617 - categorical_accuracy: 0.3294
# Epoch 88/2000
# 3/3 [==============================] - 1s 253ms/step - loss: 1806.6761 - categorical_accuracy: 0.4118
# Epoch 89/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 
2000
# 3/3 [==============================] - 1s 203ms/step - loss: 1.1101 - categorical_accuracy: 0.2706
# Epoch 134/2000
# 3/3 [==============================] - 1s 242ms/step - loss: 1.1062 - categorical_accuracy: 0.2706
# Epoch 135/2000
# 3/3 [==============================] - 1s 212ms/step - loss: 1.1031 - categorical_accuracy: 0.2706
# Epoch 136/2000
# 3/3 [==============================] - 1s 250ms/step - loss: 1.1009 - categorical_accuracy: 0.2824
# Epoch 137/2000
# 3/3 [==============================] - 1s 229ms/step - loss: 1.0983 - categorical_accuracy: 0.2941
# Epoch 138/2000
# 3/3 [==============================] - 1s 243ms/step - loss: 1.0964 - categorical_accuracy: 0.3059
# Epoch 139/2000
# 3/3 [==============================] - 1s 257ms/step - loss: 1.0947 - categorical_accuracy: 0.3294
# Epoch 140/2000
# 3/3 [==============================] - 1s 234ms/step - loss: 1.0932 - categorical_accuracy: 0.3412
# Epoch 141/2000
# 3/3 [==============================] - 1s 257ms/step - loss: 1.0918 - categorical_accuracy: 0.4471
# Epoch 142/2000
# 3/3 [==============================] - 1s 247ms/step - loss: 1.0899 - categorical_accuracy: 0.4706
# Epoch 143/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 1.0884 - categorical_accuracy: 0.4471
# Epoch 144/2000
# 3/3 [==============================] - 1s 250ms/step - loss: 1.0868 - categorical_accuracy: 0.4471
# Epoch 145/2000
# 3/3 [==============================] - 1s 286ms/step - loss: 1.0848 - categorical_accuracy: 0.4588
# Epoch 146/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 1.0830 - categorical_accuracy: 0.4235
# Epoch 147/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 1.0809 - categorical_accuracy: 0.4000
# Epoch 148/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 1.0789 - categorical_accuracy: 0.3882
# Epoch 149/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 1.0770 - categorical_accuracy: 0.3765
# Epoch 150/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 1.0754 - categorical_accuracy: 0.3765
# Epoch 151/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 1.0724 - categorical_accuracy: 0.3765
# Epoch 152/2000
# 3/3 [==============================] - 1s 229ms/step - loss: 1.0699 - categorical_accuracy: 0.3647
# Epoch 153/2000
# 3/3 [==============================] - 1s 177ms/step - loss: 1.0671 - categorical_accuracy: 0.3529
# Epoch 154/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 1.0638 - categorical_accuracy: 0.3412
# Epoch 155/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 1.0593 - categorical_accuracy: 0.3529
# Epoch 156/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 1.0554 - categorical_accuracy: 0.3647
# Epoch 157/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 1.0520 - categorical_accuracy: 0.3647
# Epoch 158/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 1.0481 - categorical_accuracy: 0.3765
# Epoch 159/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 1.0445 - categorical_accuracy: 0.3647
# Epoch 160/2000
# 3/3 [==============================] - 1s 225ms/step - loss: 1.0424 - categorical_accuracy: 0.3647
# Epoch 161/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 1.0391 - categorical_accuracy: 0.3765
# Epoch 162/2000
# 3/3 [==============================] - 1s 205ms/step - loss: 1.0372 - categorical_accuracy: 0.3647
# Epoch 163/2000
# 3/3 [==============================] - 1s 212ms/step - loss: 1.0339 - categorical_accuracy: 0.3765
# Epoch 164/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 1.0303 - categorical_accuracy: 0.3647
# Epoch 165/2000
# 3/3 [==============================] - 1s 244ms/step - loss: 1.0062 - categorical_accuracy: 0.5765
# Epoch 166/2000
# 3/3 [==============================] - 1s 236ms/step - loss: 1.0007 - categorical_accuracy: 0.6588
# Epoch 167/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 0.9975 - categorical_accuracy: 0.5882
# Epoch 168/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 3.9751 - categorical_accuracy: 0.3647
# Epoch 169/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 1.1403 - categorical_accuracy: 0.5529
# Epoch 170/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 1.0286 - categorical_accuracy: 0.5765
# Epoch 171/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 1.0290 - categorical_accuracy: 0.5647
# Epoch 172/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 1.0270 - categorical_accuracy: 0.5765
# Epoch 173/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 1.0240 - categorical_accuracy: 0.5647
# Epoch 174/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 1.0181 - categorical_accuracy: 0.5882
# Epoch 175/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 1.0152 - categorical_accuracy: 0.5882
# Epoch 176/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 1.0108 - categorical_accuracy: 0.6000
# Epoch 177/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 1101.1379 - categorical_accuracy: 0.4824
# Epoch 178/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 1.0105 - categorical_accuracy: 0.5765
# Epoch 179/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 1.0115 - categorical_accuracy: 0.5176
# Epoch 180/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 1.0109 - categorical_accuracy: 0.5529
# Epoch 181/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 1.0021 - categorical_accuracy: 0.6235
# Epoch 182/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 1.0011 - categorical_accuracy: 0.6000
# Epoch 183/2000
# 3/3 [==============================] - 1s 264ms/step - loss: 0.9896 - categorical_accuracy: 0.5294
# Epoch 184/2000
# 3/3 [==============================] - 1s 207ms/step - loss: 0.9811 - categorical_accuracy: 0.5647
# Epoch 185/2000
# 3/3 [==============================] - 1s 228ms/step - loss: 0.9667 - categorical_accuracy: 0.5647
# Epoch 186/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 31.0193 - categorical_accuracy: 0.4824
# Epoch 187/2000
# 3/3 [==============================] - 1s 214ms/step - loss: 0.9441 - categorical_accuracy: 0.5529
# Epoch 188/2000
# 3/3 [==============================] - 1s 219ms/step - loss: 0.9376 - categorical_accuracy: 0.6235
# Epoch 189/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 0.9311 - categorical_accuracy: 0.5529
# Epoch 190/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 0.9250 - categorical_accuracy: 0.5882
# Epoch 191/2000
# 3/3 [==============================] - 1s 219ms/step - loss: 0.9117 - categorical_accuracy: 0.6000
# Epoch 192/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 0.9165 - categorical_accuracy: 0.5529
# Epoch 193/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 0.9220 - categorical_accuracy: 0.6471
# Epoch 194/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 0.8847 - categorical_accuracy: 0.4941
# Epoch 195/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.8834 - categorical_accuracy: 0.5412
# Epoch 196/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.8704 - categorical_accuracy: 0.4706
# Epoch 197/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 0.8466 - categorical_accuracy: 0.5176
# Epoch 198/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.8345 - categorical_accuracy: 0.5059
# Epoch 199/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 0.8156 - categorical_accuracy: 0.5294
# Epoch 200/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 0.7809 - categorical_accuracy: 0.5412
# Epoch 201/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 0.7505 - categorical_accuracy: 0.6471
# Epoch 202/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 0.7396 - categorical_accuracy: 0.6588
# Epoch 203/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 0.7269 - categorical_accuracy: 0.7294
# Epoch 204/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 0.6998 - categorical_accuracy: 0.6706
# Epoch 205/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 0.6956 - categorical_accuracy: 0.7412
# Epoch 206/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 0.6385 - categorical_accuracy: 0.7529
# Epoch 207/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 0.6219 - categorical_accuracy: 0.7882
# Epoch 208/2000
# 3/3 [==============================] - 1s 234ms/step - loss: 0.6074 - categorical_accuracy: 0.7294
# Epoch 209/2000
# 3/3 [==============================] - 1s 213ms/step - loss: 0.5946 - categorical_accuracy: 0.7647
# Epoch 210/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 0.5889 - categorical_accuracy: 0.7765
# Epoch 211/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 0.5736 - categorical_accuracy: 0.7176
# Epoch 212/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 0.5492 - categorical_accuracy: 0.7882
# Epoch 213/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 0.5491 - categorical_accuracy: 0.7882
# Epoch 214/2000
# 3/3 [==============================] - 1s 238ms/step - loss: 0.5365 - categorical_accuracy: 0.7882
# Epoch 215/2000
# 3/3 [==============================] - 1s 228ms/step - loss: 0.6575 - categorical_accuracy: 0.6941
# Epoch 216/2000
# 3/3 [==============================] - 1s 231ms/step - loss: 0.7330 - categorical_accuracy: 0.5882
# Epoch 217/2000
# 3/3 [==============================] - 1s 237ms/step - loss: 0.6283 - categorical_accuracy: 0.7176
# Epoch 218/2000
# 3/3 [==============================] - 1s 214ms/step - loss: 0.5260 - categorical_accuracy: 0.8353
# Epoch 219/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5289 - categorical_accuracy: 0.8118
# Epoch 220/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 0.5223 - categorical_accuracy: 0.7765
# Epoch 221/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 0.5087 - categorical_accuracy: 0.7294
# Epoch 222/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 0.4800 - categorical_accuracy: 0.8471
# Epoch 223/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.4989 - categorical_accuracy: 0.7647
# Epoch 224/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.5981 - categorical_accuracy: 0.7647
# Epoch 225/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.5175 - categorical_accuracy: 0.7529
# Epoch 226/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 0.4869 - categorical_accuracy: 0.8588
# Epoch 227/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 0.4556 - categorical_accuracy: 0.8706
# Epoch 228/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 0.4556 - categorical_accuracy: 0.8353
# Epoch 229/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 0.4832 - categorical_accuracy: 0.8588
# Epoch 230/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 0.4590 - categorical_accuracy: 0.8588
# Epoch 231/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 0.4638 - categorical_accuracy: 0.8353
# Epoch 232/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 0.4335 - categorical_accuracy: 0.8471
# Epoch 233/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 0.4628 - categorical_accuracy: 0.8118
# Epoch 234/2000
# 3/3 [==============================] - 1s 223ms/step - loss: 0.4736 - categorical_accuracy: 0.8118
# Epoch 235/2000
# 3/3 [==============================] - 1s 218ms/step - loss: 0.5374 - categorical_accuracy: 0.7294
# Epoch 236/2000
# 3/3 [==============================] - 1s 235ms/step - loss: 0.5020 - categorical_accuracy: 0.7647
# Epoch 237/2000
# 3/3 [==============================] - 1s 223ms/step - loss: 0.4780 - categorical_accuracy: 0.7882
# Epoch 238/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 0.4359 - categorical_accuracy: 0.8353
# Epoch 239/2000
# 3/3 [==============================] - 1s 226ms/step - loss: 0.4457 - categorical_accuracy: 0.8471
# Epoch 240/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 0.4611 - categorical_accuracy: 0.7647
# Epoch 241/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 0.4405 - categorical_accuracy: 0.7882
# Epoch 242/2000
# 3/3 [==============================] - 1s 230ms/step - loss: 0.4003 - categorical_accuracy: 0.8588
# Epoch 243/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 0.4156 - categorical_accuracy: 0.8588
# Epoch 244/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 0.4109 - categorical_accuracy: 0.7765
# Epoch 245/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3856 - categorical_accuracy: 0.8353
# Epoch 246/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.3876 - categorical_accuracy: 0.8588
# Epoch 247/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.3689 - categorical_accuracy: 0.8588
# Epoch 248/2000
# 3/3 [==============================] - 1s 209ms/step - loss: 0.3614 - categorical_accuracy: 0.8353
# Epoch 249/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 0.3558 - categorical_accuracy: 0.8235
# Epoch 250/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 0.3413 - categorical_accuracy: 0.8471
# Epoch 251/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 0.3404 - categorical_accuracy: 0.8471
# Epoch 252/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.3315 - categorical_accuracy: 0.8706
# Epoch 253/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 0.3260 - categorical_accuracy: 0.8706
# Epoch 254/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3207 - categorical_accuracy: 0.8824
# Epoch 255/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 0.3133 - categorical_accuracy: 0.8706
# Epoch 256/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 0.3066 - categorical_accuracy: 0.8824
# Epoch 257/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.3306 - categorical_accuracy: 0.8706
# Epoch 258/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 0.3181 - categorical_accuracy: 0.8588
# Epoch 259/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 0.3447 - categorical_accuracy: 0.8824
# Epoch 260/2000
# 3/3 [==============================] - 1s 243ms/step - loss: 0.3537 - categorical_accuracy: 0.8706
# Epoch 261/2000
# 3/3 [==============================] - 1s 251ms/step - loss: 0.3515 - categorical_accuracy: 0.8706
# Epoch 262/2000
# 3/3 [==============================] - 1s 230ms/step - loss: 0.3570 - categorical_accuracy: 0.8588
# Epoch 263/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 0.3730 - categorical_accuracy: 0.8706
# Epoch 264/2000
# 3/3 [==============================] - 1s 230ms/step - loss: 0.3671 - categorical_accuracy: 0.8588
# Epoch 265/2000
# 3/3 [==============================] - 1s 228ms/step - loss: 0.3559 - categorical_accuracy: 0.8706
# Epoch 266/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3452 - categorical_accuracy: 0.8706
# Epoch 267/2000
# 3/3 [==============================] - 1s 213ms/step - loss: 0.3395 - categorical_accuracy: 0.8588
# Epoch 268/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3483 - categorical_accuracy: 0.8471
# Epoch 269/2000
# 3/3 [==============================] - 1s 217ms/step - loss: 0.3179 - categorical_accuracy: 0.9059
# Epoch 270/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3344 - categorical_accuracy: 0.8941
# Epoch 271/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 0.3123 - categorical_accuracy: 0.9059
# Epoch 272/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 0.3040 - categorical_accuracy: 0.9176
# Epoch 273/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2997 - categorical_accuracy: 0.9059
# Epoch 274/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2845 - categorical_accuracy: 0.9059
# Epoch 275/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2788 - categorical_accuracy: 0.9059
# Epoch 276/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2811 - categorical_accuracy: 0.8941
# Epoch 277/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2773 - categorical_accuracy: 0.8941
# Epoch 278/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 0.2749 - categorical_accuracy: 0.8941
# Epoch 279/2000
# 3/3 [==============================] - 1s 241ms/step - loss: 0.2754 - categorical_accuracy: 0.8706
# Epoch 280/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.2747 - categorical_accuracy: 0.8706
# Epoch 281/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0
2000
# 3/3 [==============================] - 1s 185ms/step - loss: 5084.6499 - categorical_accuracy: 0.3294
# Epoch 334/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 9957.4004 - categorical_accuracy: 0.3529
# Epoch 335/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 4508.8027 - categorical_accuracy: 0.3294
# Epoch 336/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 2434.5979 - categorical_accuracy: 0.2000
# Epoch 337/2000
# 3/3 [==============================] - 1s 176ms/step - loss: 1766.9888 - categorical_accuracy: 0.3059
# Epoch 338/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 676.6677 - categorical_accuracy: 0.2941
# Epoch 339/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 705.7486 - categorical_accuracy: 0.3294
# Epoch 340/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 460.6682 - categorical_accuracy: 0.2941
# Epoch 341/2000
# 3/3 [==============================] - 1s 209ms/step - loss: 427.1199 - categorical_accuracy: 0.3294
# Epoch 342/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 291.9161 - categorical_accuracy: 0.3294
# Epoch 343/2000
# 3/3 [==============================] - 1s 253ms/step - loss: 315.7323 - categorical_accuracy: 0.2941
# Epoch 344/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 202.8295 - categorical_accuracy: 0.3176
# Epoch 345/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 225.1102 - categorical_accuracy: 0.2235
# Epoch 346/2000
# 3/3 [==============================] - 1s 168ms/step - loss: 119.5990 - categorical_accuracy: 0.3412
# Epoch 347/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 187.2254 - categorical_accuracy: 0.2824
# Epoch 348/2000
# 3/3 [==============================] - 1s 181ms/step - loss: 117.4020 - categorical_accuracy: 0.3529
# Epoch 349/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 1604.4790 - categorical_accuracy: 0.2824
# Epoch 350/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 864.7859 - categorical_accuracy: 0.3294
# Epoch 351/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 1073.0771 - categorical_accuracy: 0.3294
# Epoch 352/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 374.1544 - categorical_accuracy: 0.4588
# Epoch 353/2000
# 3/3 [==============================] - 1s 180ms/step - loss: 260.1677 - categorical_accuracy: 0.3647
# Epoch 354/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 316.2788 - categorical_accuracy: 0.3059
# Epoch 355/2000
# 3/3 [==============================] - 1s 182ms/step - loss: 606.8676 - categorical_accuracy: 0.3059
# Epoch 356/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 590.0707 - categorical_accuracy: 0.3294
# Epoch 357/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 439.5429 - categorical_accuracy: 0.3294
# Epoch 358/2000
# 3/3 [==============================] - 1s 175ms/step - loss: 521.6295 - categorical_accuracy: 0.3412
# Epoch 359/2000
# 3/3 [==============================] - 1s 369ms/step - loss: 171.5069 - categorical_accuracy: 0.4000
# Epoch 360/2000
# 3/3 [==============================] - 1s 197ms/step - loss: 75.2116 - categorical_accuracy: 0.3176
# Epoch 361/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 95.8700 - categorical_accuracy: 0.3412
# Epoch 362/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 110.0127 - categorical_accuracy: 0.3294
# Epoch 363/2000
# 3/3 [==============================] - 1s 217ms/step - loss: 52.7178 - categorical_accuracy: 0.3529
# Epoch 364/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 37.8732 - categorical_accuracy: 0.2824
# Epoch 365/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 26.4272 - categorical_accuracy: 0.3176
# Epoch 366/2000
# 3/3 [==============================] - 1s 224ms/step - loss: 12.0914 - categorical_accuracy: 0.3412
# Epoch 367/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 10.9642 - categorical_accuracy: 0.4824
# Epoch 368/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 13.3507 - categorical_accuracy: 0.4118
# Epoch 369/2000
# 3/3 [==============================] - 1s 251ms/step - loss: 12.6900 - categorical_accuracy: 0.5647
# Epoch 370/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 10.7384 - categorical_accuracy: 0.5412
# Epoch 371/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 8.5269 - categorical_accuracy: 0.4118
# Epoch 372/2000
# 3/3 [==============================] - 1s 214ms/step - loss: 6.0957 - categorical_accuracy: 0.4824
# Epoch 373/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 5.0051 - categorical_accuracy: 0.3647
# Epoch 374/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 4.9836 - categorical_accuracy: 0.4706
# Epoch 375/2000
# 3/3 [==============================] - 1s 223ms/step - loss: 8.6057 - categorical_accuracy: 0.3529
# Epoch 376/2000
# 3/3 [==============================] - 1s 226ms/step - loss: 9.6074 - categorical_accuracy: 0.5059
# Epoch 377/2000
# 3/3 [==============================] - 1s 216ms/step - loss: 7.9674 - categorical_accuracy: 0.4706
# Epoch 378/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 7.2773 - categorical_accuracy: 0.4706
# Epoch 379/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 5.1958 - categorical_accuracy: 0.5647
# Epoch 380/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 3.6668 - categorical_accuracy: 0.5647
# Epoch 381/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 2.9085 - categorical_accuracy: 0.4235
# Epoch 382/2000
# 3/3 [==============================] - 1s 208ms/step - loss: 3.0501 - categorical_accuracy: 0.3412
# Epoch 383/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 3.5471 - categorical_accuracy: 0.4824
# Epoch 384/2000
# 3/3 [==============================] - 1s 231ms/step - loss: 2.6143 - categorical_accuracy: 0.5882
# Epoch 385/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 2.6106 - categorical_accuracy: 0.4588
# Epoch 386/2000
# 3/3 [==============================] - 1s 187ms/step - loss: 2.0437 - categorical_accuracy: 0.5529
# Epoch 387/2000
# 3/3 [==============================] - 1s 205ms/step - loss: 2.3346 - categorical_accuracy: 0.5176
# Epoch 388/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 2.1431 - categorical_accuracy: 0.4235
# Epoch 389/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 1.7164 - categorical_accuracy: 0.6235
# Epoch 390/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 2.0598 - categorical_accuracy: 0.4824
# Epoch 391/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 1.9996 - categorical_accuracy: 0.5647
# Epoch 392/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 1.8647 - categorical_accuracy: 0.5176
# Epoch 393/2000
# 3/3 [==============================] - 1s 217ms/step - loss: 3.0038 - categorical_accuracy: 0.4588
# Epoch 394/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 2.4555 - categorical_accuracy: 0.4941
# Epoch 395/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 3.2585 - categorical_accuracy: 0.6118
# Epoch 396/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 2.7001 - categorical_accuracy: 0.4588
# Epoch 397/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 2.0583 - categorical_accuracy: 0.4118
# Epoch 398/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 2.3405 - categorical_accuracy: 0.5647
# Epoch 399/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 2.5816 - categorical_accuracy: 0.4941
# Epoch 400/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 2.2808 - categorical_accuracy: 0.4941
# Epoch 401/2000
# 3/3 [==============================] - 1s 217ms/step - loss: 1.9079 - categorical_accuracy: 0.5529
# Epoch 402/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 1.8915 - categorical_accuracy: 0.5765
# Epoch 403/2000
# 3/3 [==============================] - 1s 209ms/step - loss: 1.5895 - categorical_accuracy: 0.5412
# Epoch 404/2000
# 3/3 [==============================] - 1s 210ms/step - loss: 1.6304 - categorical_accuracy: 0.5176
# Epoch 405/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 1.4428 - categorical_accuracy: 0.5529
# Epoch 406/2000
# 3/3 [==============================] - 1s 195ms/step - loss: 1.4287 - categorical_accuracy: 0.5765
# Epoch 407/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 1.3607 - categorical_accuracy: 0.6000
# Epoch 408/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 1.3654 - categorical_accuracy: 0.6000
# Epoch 409/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 1.2896 - categorical_accuracy: 0.6471
# Epoch 410/2000
# 3/3 [==============================] - 1s 188ms/step - loss: 1.2958 - categorical_accuracy: 0.6000
# Epoch 411/2000
# 3/3 [==============================] - 1s 184ms/step - loss: 1.4300 - categorical_accuracy: 0.6000
# Epoch 412/2000
# 3/3 [==============================] - 1s 198ms/step - loss: 1.2830 - categorical_accuracy: 0.6353
# Epoch 413/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 1.2341 - categorical_accuracy: 0.6118
# Epoch 414/2000
# 3/3 [==============================] - 1s 194ms/step - loss: 1.2317 - categorical_accuracy: 0.6471
# Epoch 415/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 1.6770 - categorical_accuracy: 0.5176
# Epoch 416/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 1.5707 - categorical_accuracy: 0.4824
# Epoch 417/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 1.6538 - categorical_accuracy: 0.5529
# Epoch 418/2000
# 3/3 [==============================] - 1s 211ms/step - loss: 1.8473 - categorical_accuracy: 0.6706
# Epoch 419/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 1.6862 - categorical_accuracy: 0.6000
# ...
# Epoch 1862/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7399 - categorical_accuracy: 0.6353
# Epoch 1863/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 0.7698 - categorical_accuracy: 0.6353
# Epoch 1864/2000
# 3/3 [==============================] - 1s 214ms/step - loss: 0.9937 - categorical_accuracy: 0.5412
# Epoch 1865/2000
# 3/3 [==============================] - 1s 228ms/step - loss: 0.6880 - categorical_accuracy: 0.6824
# Epoch 1866/2000
# 3/3 [==============================] - 1s 214ms/step - loss: 0.5970 - categorical_accuracy: 0.6941
# Epoch 1867/2000
# 3/3 [==============================] - 1s 202ms/step - loss: 0.5735 - categorical_accuracy: 0.7765
# Epoch 1868/2000
# 3/3 [==============================] - 1s 222ms/step - loss: 0.6252 - categorical_accuracy: 0.7412
# Epoch 1869/2000
# 3/3 [==============================] - 1s 237ms/step - loss: 0.8667 - categorical_accuracy: 0.5882
# Epoch 1870/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 0.6675 - categorical_accuracy: 0.6824
# Epoch 1871/2000
# 3/3 [==============================] - 1s 219ms/step - loss: 0.8124 - categorical_accuracy: 0.7176
# Epoch 1872/2000
# 3/3 [==============================] - 1s 220ms/step - loss: 0
2000
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3437 - categorical_accuracy: 0.9294
# Epoch 1992/2000
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3185 - categorical_accuracy: 0.9176
# Epoch 1993/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2998 - categorical_accuracy: 0.9176
# Epoch 1994/2000
# 3/3 [==============================] - 1s 205ms/step - loss: 0.2917 - categorical_accuracy: 0.9176
# Epoch 1995/2000
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2921 - categorical_accuracy: 0.8941
# Epoch 1996/2000
# 3/3 [==============================] - 1s 224ms/step - loss: 0.2877 - categorical_accuracy: 0.9176
# Epoch 1997/2000
# 3/3 [==============================] - 1s 203ms/step - loss: 0.2933 - categorical_accuracy: 0.9294
# Epoch 1998/2000
# 3/3 [==============================] - 1s 227ms/step - loss: 0.3001 - categorical_accuracy: 0.9176
# Epoch 1999/2000
# 3/3 [==============================] - 1s 231ms/step - loss: 0.2806 - categorical_accuracy: 0.9176
# Epoch 2000/2000
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2619 - categorical_accuracy: 0.9176

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 30, 64)            442112
#
#  lstm_13 (LSTM)              (None, 30, 128)           98816
#
#  lstm_14 (LSTM)              (None, 64)                49408
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  dense_18 (Dense)            (None, 32)                2080
#
#  dense_19 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'thanks'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5.keras')

# %%
del model

# %%
model = Sequential()
model.load_weights('action.h5.keras')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
# Assuming you have imported the necessary libraries and defined your model

# Make predictions
yhat = model.predict(X_test)

# Process predictions and true labels
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
# Out:
# 1/1 [==============================] - 0s 89ms/step

# %%
# yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [1, 1]],
#
#        [[3, 0],
#         [2, 0]],
#
#        [[4, 0],
#         [1, 0]],
#
#        [[3, 2],
#         [0, 0]],
#
#        [[4, 1],
#         [0, 0]],
#
#        [[4, 1],
#         [0, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.2

# %% [markdown]
# # 11. Test in Real Time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[164], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[163], line 9, in prob_viz(res, actions, input_frame, colors)
#       6 output_frame = input_frame.copy()
#       7 for num, prob in enumerate(res):
#       8     # Convert the probability to an integer percentage for the rectangle width
# ----> 9     prob_percentage = int(prob * 100)
#      11     # Use a tuple for the second argument of cv2.rectangle
#      12     start_point = (0, 60 + num * 40)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
sequence.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 sequence.reverse()
#
# AttributeError: 'int' object has no attribute 'reverse'

# %%
len(sequence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 len(sequence)
#
# TypeError: object of type 'int' has no len()

# %%
sequence.append('def')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 sequence.append('def')
#
# AttributeError: 'int' object has no attribute 'append'

# %%
sequence.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 sequence.reverse()
#
# AttributeError: 'int' object has no attribute 'reverse'

# %%
sequence[-30:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 sequence[-30:]
#
# TypeError: 'int' object is not subscriptable

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[170], line 30
#      28 if len(sequence) == 30:
#      29     res = model.predict(np.expand_dims(sequence, axis=0))[0]
# ---> 30     print(actions[np.argmax(res)])
#      33 #3. Viz logic
#      34     if res[np.argmax(res)] > threshold:
#
# IndexError: index 44999 is out of bounds for axis 0 with size 3

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)] > threshold
# Out:
# array([False, False, False])

# %%
(num_sequences,30,1662)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 (num_sequences,30,1662)
#
# NameError: name 'num_sequences' is not defined

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 model.predict(np.expand_dims(X_test[0], axis=0))
#
# NameError: name 'model' is not defined
